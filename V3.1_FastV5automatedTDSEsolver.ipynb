# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.linalg import expm, eigh
import os
# %matplotlib widget

# Atomic Unit Conversion
au_time = 2.4188843265864e-2 # fs
hartree_energy = 27.211386245981 # eV
au_time_conversion = 1 / au_time # from fs to au_time
au_energy_conversion = 1 / hartree_energy # from eV to au_energy

os.chdir('/asap3/flash/gpfs/fl26/2023/data/11015602/shared/Harijyoti/')
os.getcwd()

def C_t(t, t_min, t_max, delta_T):
    return np.where(
        t < t_min - delta_T, 0,
        np.where(t < t_min, np.sin((t - (t_min - delta_T)) * (np.pi / (2 * delta_T))) ** 2,
        np.where(t <= t_max, 1,
        np.where(t <= t_max + delta_T, np.cos((t - t_max) * (np.pi / (2 * delta_T))) ** 2, 0))))

# Function for E_omega (fundamental frequency)
def E_omega(t, E0, E02, omega, t0, tau, phi_w, phi_2w):
    envelope = np.exp(-((t - t0) / tau) ** 2)
    oscillation_w = np.cos(omega * t + phi_w)
    oscillation_2w = np.cos(2 * omega * t + phi_2w)  # Second harmonic = 2 * omega
    return (E0 * envelope * oscillation_w + E02 * envelope * oscillation_2w )* C_t(t, t_min, t_max, delta_T)

# %%
# Define energy levels (in eV)
energy_levels = {
    '1s': -24.6,
    '1s2p': -3.4,
    's': 17.8,
    'p': 17.8,
    'd': 17.8
}



# Energies and dipole elements
omega_s_eV = energy_levels['1s']
omega_p_eV = energy_levels['1s2p']
omega_es_eV = energy_levels['s']
omega_ep_eV = energy_levels['p']
omega_ed_eV = energy_levels['d']

# Convert energies from eV to atomic units
omega_s = omega_s_eV * au_energy_conversion
omega_p = omega_p_eV * au_energy_conversion
omega_es = omega_es_eV * au_energy_conversion
omega_ep = omega_ep_eV * au_energy_conversion
omega_ed = omega_ed_eV * au_energy_conversion
# Print converted energies for verification
# print(f"omega_s: {omega_s} au")
# print(f"omega_p: {omega_p} au")
# print(f"omega_es: {omega_es} au")
# print(f"omega_ep: {omega_ep} au")
# print(f"omega_ed: {omega_ed} au")


# Define x-axis positions for the levels
x_positions = {
    '1s': 0,
    '1s2p': 1,
    's': 0,
    'p': 1,
    'd': 2
}

# Define transitions (start and end points)
transitions = [
    ('1s', '1s2p', '\u03C9', 'red'),
    ('1s2p', 's', '\u03C9', 'red'),
    ('1s2p', 'd', '\u03C9', 'red'),
    ('1s', 'p', '2\u03C9', 'blue')
]

# Create the plot
fig, ax = plt.subplots()

# Plot energy levels
for level, energy in energy_levels.items():
    ax.hlines(energy, xmin=x_positions[level] - 0.2, xmax=x_positions[level] + 0.2, color='black')
    ax.text(x_positions[level] + 0.3, energy, level, verticalalignment='center')

# Plot transitions
for start, end, label, color in transitions:
    ax.annotate('', xy=(x_positions[end], energy_levels[end]), xytext=(x_positions[start], energy_levels[start]),
                arrowprops=dict(arrowstyle='<->', color=color))
    ax.text((x_positions[start] + x_positions[end]) / 2, (energy_levels[start] + energy_levels[end]) / 2, label, color=color)

ax.axhline(y=0, color='gray', linestyle='--', label='Zero Energy')

# Set plot limits and labels
ax.set_xlim(-0.5, 2.5)
ax.set_ylim(-30, 20)
ax.set_ylabel('Energy (eV)')
ax.set_xticks([0, 1, 2])
ax.set_xticklabels(['l=0', 'l=1', 'l=2'])
ax.set_yticks(list(energy_levels.values()))
ax.set_title('5-Level Helium Model')

# Show the plot
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Time array(in fs)
start_time, stop_time = -200,200  # fs
steps = 1000  # steps
t_values_SI = np.linspace(start_time, stop_time, steps)  # Time array in femtoseconds
dt_SI = t_values_SI[1]- t_values_SI[0]
print(f'Time Step is {np.round(dt_SI*1000, decimals =2)} attoseconds')
t_values = t_values_SI *au_time_conversion  # Time array in atomic units
# Time step
dt = t_values[1] - t_values[0]
# Electric Field parameters
phi_w = 0.0
phi_2w = 0.0
tau = 50  # fs
tau_au = tau * au_time_conversion
t0 = 0 # fs  # setting t0 to a non-zero value to avoid zero limit issue
t0_au = t0 * au_time_conversion
E0_au = 0.0005
E02_au = 0.00005
omega = 21.2*au_energy_conversion

# Markers and annotations
t_min = -(tau-5)*au_time_conversion*3
t_max = (tau-5)*au_time_conversion*3
delta_T = dt*10

E_om = E_omega(t_values, E0_au, E02_au, omega, t0_au, tau_au, phi_w, phi_2w)

plt.figure()
plt.scatter(t_values_SI, E_om, label='$E_{\omega}(t)$', color='b')
plt.axvline(t_min*au_time, linestyle='--', color='gray', label='$t_{\min}$')
plt.axvline(t_max*au_time, linestyle='--', color='gray', label='$t_{\max}$')
plt.axvline((t_min - delta_T)*au_time, linestyle=':', color='red', label='$t_{\min} - \Delta T$')
plt.axvline((t_max + delta_T)*au_time, linestyle=':', color='red', label='$t_{\max} + \Delta T$')
plt.xlabel('$t (\mathrm{fs})$')
plt.ylabel('$E(t) \ (\mathrm{arb.\ unit})$')
plt.title('Electric Field with Filter Function $C(t)$')
plt.legend()
plt.grid()
plt.show()
# Out:
# Time Step is 400.4 attoseconds
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Initial Hamiltonian without the field
H0 = np.array([
    [omega_s, 0, 0, 0, 0],
    [0, omega_p, 0, 0, 0],
    [0, 0, omega_es, 0, 0],
    [0, 0, 0, omega_ep, 0],
    [0, 0, 0, 0, omega_ed]
], dtype=complex)


# Define the decay term in atomic units
decay = au_energy_conversion*1j  #1 eV decay
H0[2, 2] -= decay  # omega_es
H0[3, 3] -= decay  # omega_ep
H0[4, 4] -= decay  # omega_ed

# Hamiltonian function
def dipole_matrix(d_ped, d_pes, d_sep, d_sp):
    return np.array([
        [0, d_sp, 0, d_sep, 0],
        [d_sp, 0, d_pes, 0, d_ped],
        [0, d_pes, 0, 0, 0],
        [d_sep, 0, 0, 0, 0],
        [0, d_ped, 0, 0, 0]
    ], dtype=complex)

# %%
# Define dipole matrix elements
# d_pes, d_sep, d_ped = 0.001, 0.0002, 0.0015
d_sp = 0.45
d_pes, d_sep, d_ped = 0.0015, 0.00015, 0.001

# Calculate dipole matrix element
dme = dipole_matrix(d_ped, d_pes, d_sep, d_sp)
# Diagonalize the dipole matrix
dme_eigenvalues, dme_eigenvectors = eigh(dme)
Diagonal_dme = np.diag(dme_eigenvalues)
# Reconstruct the original dipole matrix using its eigenvalues and eigenvectors
# reconstructed_dme = np.dot(dme_eigenvectors, np.dot(Diagonal_dme, dme_eigenvectors.T.conj()))

# print("Original dipole matrix (dme):")
# print(dme)
# print("\nEigenvalues of the dipole matrix:")
# print(dme_eigenvalues)
# print("\nEigenvectors of the dipole matrix:")
# print(dme_eigenvectors)
# print("\nReconstructed dipole matrix:")
# print(reconstructed_dme)

# # Check if the reconstructed matrix is close to the original matrix
# if np.allclose(dme, reconstructed_dme):
#     print("\nThe reconstructed matrix is close to the original matrix.")
# else:
#     print("\nThere is a discrepancy between the original and reconstructed matrices.")

# %%
def tdse_solver(omega_ev):
    omega_au = omega_ev*au_energy_conversion
    E_om = E_omega(t_values, E0_au, E02_au, omega_au, t0_au, tau_au, phi_w, phi_2w)
    dfs = {} # DataFrames for the all the populations at each time step
    # Initial state
    psi_0 = np.array([1, 0, 0, 0, 0], dtype=complex)
    psi_t_list = [psi_0]
    U0_half_dt = expm(-1j * H0 * dt / 2)
    for index in range(len(t_values[1:])):
        EF = E_om[index]
        psi_dt = psi_t_list[index]
        psi_0_u0 = np.dot(U0_half_dt, psi_dt)
        psi_0_eigenbasis = np.dot(dme_eigenvectors.T.conj(), psi_0_u0)
        u_t = np.exp(-1j *EF* Diagonal_dme * dt )
        psi_t_eigenbasis = np.dot(u_t, psi_0_eigenbasis)
        psi_t_pre = np.dot(dme_eigenvectors, psi_t_eigenbasis)
        psi_t_u0 = np.dot(U0_half_dt, psi_t_pre)
        # Check for NaN values
        if np.isnan(psi_t_u0).any():
            print(f"NaN detected at time step {index}, EF: {EF}")
            print(f"Intermediate values at time step {index}:")
            print(f"psi_0_u0: {psi_0_u0}")
            print(f"psi_0_eigenbasis: {psi_0_eigenbasis}")
            print(f"u_t: {u_t}")
            print(f"psi_t_eigenbasis: {psi_t_eigenbasis}")
            print(f"psi_t_pre: {psi_t_pre}")
            break
        psi_t_list.append(psi_t_u0)
    psi_t_array = np.array(psi_t_list)
    dfs[f'df_psi_{round(omega_ev,4)}'] = pd.DataFrame(psi_t_array, columns=['s', 'p', 'es', 'ep', 'ed'])
    return dfs

# %%
dfs['df_psi_21.2']['s'][580]
# Out:
# (nan+nanj)

# %%
t_values_SI[460]
# Out:
# -198.159981599816

# %%
omega_ev = 21.2
print(f"Running simulation for omega = {round(omega_ev, 3)} eV")
dfs = tdse_solver(omega_ev)
print(f"Completed simulation for omega = {round(omega_ev, 3)} eV")
# Out:
# Running simulation for omega = 21.2 eV
# NaN detected at time step 577, EF: 0.00033031219573309844
# Intermediate values at time step 577:
# psi_0_u0: [ 8.49823713e+304-7.98483045e+304j  1.41090762e+308+4.96746496e+307j
#   3.19204619e+307+2.74626704e+305j -8.13543137e+307-7.00462725e+305j
#  -4.78806213e+307-4.12392891e+305j]
# psi_0_eigenbasis: [-9.96869626e+307-3.51815761e+307j -5.75596512e+307-5.06961578e+305j
#  -5.75453715e+307-4.95467113e+305j -5.75592259e+307-5.07058730e+305j
#  -9.98071450e+307-3.50686530e+307j]
# u_t: [[0.99999697+2.46047862e-03j 1.        +0.00000000e+00j
#   1.        +0.00000000e+00j 1.        +0.00000000e+00j
#   1.        +0.00000000e+00j]
#  [1.        +0.00000000e+00j 1.        +3.28564719e-09j
#   1.        +0.00000000e+00j 1.        +0.00000000e+00j
#   1.        +0.00000000e+00j]
#  [1.        +0.00000000e+00j 1.        +0.00000000e+00j
#   1.        +0.00000000e+00j 1.        +0.00000000e+00j
#   1.        +0.00000000e+00j]
#  [1.        +0.00000000e+00j 1.        +0.00000000e+00j
#   1.        +0.00000000e+00j 1.        -3.28564720e-09j
#   1.        +0.00000000e+00j]
#  [1.        +0.00000000e+00j 1.        +0.00000000e+00j
#   1.        +0.00000000e+00j 1.        +0.00000000e+00j
#   0.99999697-2.46047862e-03j]]
# psi_t_eigenbasis: [-inf+nanj -inf+nanj -inf+nanj -inf+nanj -inf+nanj]
# psi_t_pre: [nan+nanj nan+nanj nan+nanj nan+nanj nan+nanj]
# Completed simulation for omega = 21.2 eV

# %%
len(np.abs(dfs['df_psi_21.2']['es'])**2)
# Out:
# 100000

# %%
dfs['df_psi_21.2']['s']
# Out:
# 0        1.000000e+00+0.000000e+                    00j
# 1        2.128030e-23+3.205300e-                    24j
# 2        1.065326e-22+9.943186e-                    24j
# 3        5.316353e-22+1.948286e-                    23j
# 4        2.644522e-21-5.237376e-                    23j
#                               ...
# 99995                       NaN+                   NaNj
# 99996                       NaN+                   NaNj
# 99997                       NaN+                   NaNj
# 99998                       NaN+                   NaNj
# 99999                       NaN+                   NaNj
# Name: s, Length: 100000, dtype: complex128

# %%
plt.figure()
plt.plot(np.abs(dfs['df_psi_21.2']['s'])**2)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.figure()
plt.plot(t_values_SI,np.abs(dfs['df_psi_21.2']['s'])**2)
#plt.plot(t_values_SI,np.abs(dfs['df_psi_21.2']['p'])**2)
#plt.scatter(t_values, E_field/1e7, label='$E_{\omega}(t)$', color='r')
#plt.plot(t_values_SI, np.abs(dfs['df_psi_21.2']['es'])**2, label = 'es')
#plt.plot(t_values_SI, np.abs(dfs['df_psi_21.2']['ep'])**2, label = 'ep')
#plt.plot(t_values_SI, np.abs(dfs['df_psi_21.2']['ed'])**2, label = 'ed')

#plt.legend()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Running simulations for a range of omega values
steps_eV = 0.001
omega_values = np.round(np.arange(21.1, 21.3, steps_eV), 3)
results_dfs = {}
results_dfp = {}

# Create output directory if it does not exist
output_dir = f'simulation_results_optimisized_{tau}fs_V4.2'
os.makedirs(output_dir, exist_ok=True)

for omega_ev in omega_values:
    print(f"Running simulation for omega = {round(omega_ev, 3)} eV")
    dfs1, dfp1 = tdse_solver(omega_ev)
    dfs1[f'df_psi_{omega_ev}'].to_csv(os.path.join(output_dir, f'psi_t_stepseV_{steps_eV}_{round(omega_ev, 3)}_d_sep_{d_sep}_d_pes{d_pes}_d_ped_{d_ped}.csv'), index=False)
    dfp1[f'df_pop_{omega_ev}'].to_csv(os.path.join(output_dir, f'pop_t_stepseV_{steps_eV}_{round(omega_ev, 3)}_d_sep_{d_sep}_d_pes{d_pes}_d_ped_{d_ped}.csv'), index=False)
    results_dfs.update(dfs1)
    results_dfp.update(dfp1)
    print(f"Completed simulation for omega = {round(omega_ev, 3)} eV")

# Save dictionary objects
results_dfs_path = os.path.join(output_dir, f"results_dfs_stepseV_{steps_eV}_d_sep_{d_sep}_d_pes{d_pes}_d_ped_{d_ped}.pkl")
results_dfp_path = os.path.join(output_dir, f"results_dfp_stepseV_{steps_eV}_d_sep_{d_sep}_d_pes{d_pes}_d_ped_{d_ped}.pkl")

pd.to_pickle(results_dfs, results_dfs_path)
pd.to_pickle(results_dfp, results_dfp_path)

print(f"All simulations completed and results saved to {output_dir}")
# Out:
# Running simulation for omega = 21.1 eV
# Completed simulation for omega = 21.1 eV
# Running simulation for omega = 21.101 eV
# Completed simulation for omega = 21.101 eV
# Running simulation for omega = 21.102 eV
# Completed simulation for omega = 21.102 eV
# Running simulation for omega = 21.103 eV
# Completed simulation for omega = 21.103 eV
# Running simulation for omega = 21.104 eV
# Completed simulation for omega = 21.104 eV
# Running simulation for omega = 21.105 eV
# Completed simulation for omega = 21.105 eV
# Running simulation for omega = 21.106 eV
# Completed simulation for omega = 21.106 eV
# Running simulation for omega = 21.107 eV
# Completed simulation for omega = 21.107 eV
# Running simulation for omega = 21.108 eV
# Completed simulation for omega = 21.108 eV
# Running simulation for omega = 21.109 eV
# Completed simulation for omega = 21.109 eV
# Running simulation for omega = 21.11 eV
# Completed simulation for omega = 21.11 eV
# Running simulation for omega = 21.111 eV
# Completed simulation for omega = 21.111 eV
# Running simulation for omega = 21.112 eV
# Completed simulation for omega = 21.112 eV
# Running simulation for omega = 21.113 eV
# Completed simulation for omega = 21.113 eV
# Running simulation for omega = 21.114 eV
# Completed simulation for omega = 21.114 eV
# Running simulation for omega = 21.115 eV
# Completed simulation for omega = 21.115 eV
# Running simulation for omega = 21.116 eV
# Completed simulation for omega = 21.116 eV
# Running simulation for omega = 21.117 eV
# Completed simulation for omega = 21.117 eV
# Running simulation for omega = 21.118 eV
# Completed simulation for omega = 21.118 eV
# Running simulation for omega = 21.119 eV
# Completed simulation for omega = 21.119 eV
# Running simulation for omega = 21.12 eV
# Completed simulation for omega = 21.12 eV
# Running simulation for omega = 21.121 eV
# Completed simulation for omega = 21.121 eV
# Running simulation for omega = 21.122 eV
# Completed simulation for omega = 21.122 eV
# Running simulation for omega = 21.123 eV
# Completed simulation for omega = 21.123 eV
# Running simulation for omega = 21.124 eV
# Completed simulation for omega = 21.124 eV
# Running simulation for omega = 21.125 eV
# Completed simulation for omega = 21.125 eV
# Running simulation for omega = 21.126 eV
# Completed simulation for omega = 21.126 eV
# Running simulation for omega = 21.127 eV
# Completed simulation for omega = 21.127 eV
# Running simulation for omega = 21.128 eV
# Completed simulation for omega = 21.128 eV
# Running simulation for omega = 21.129 eV
# Completed simulation for omega = 21.129 eV
# Running simulation for omega = 21.13 eV
# Completed simulation for omega = 21.13 eV
# Running simulation for omega = 21.131 eV
# Completed simulation for omega = 21.131 eV
# Running simulation for omega = 21.132 eV
# Completed simulation for omega = 21.132 eV
# Running simulation for omega = 21.133 eV
# Completed simulation for omega = 21.133 eV
# Running simulation for omega = 21.134 eV
# Completed simulation for omega = 21.134 eV
# Running simulation for omega = 21.135 eV
# Completed simulation for omega = 21.135 eV
# Running simulation for omega = 21.136 eV
# Completed simulation for omega = 21.136 eV
# Running simulation for omega = 21.137 eV
# Completed simulation for omega = 21.137 eV
# Running simulation for omega = 21.138 eV
# Completed simulation for omega = 21.138 eV
# Running simulation for omega = 21.139 eV
# Completed simulation for omega = 21.139 eV
# Running simulation for omega = 21.14 eV
# Completed simulation for omega = 21.14 eV
# Running simulation for omega = 21.141 eV
# Completed simulation for omega = 21.141 eV
# Running simulation for omega = 21.142 eV
# Completed simulation for omega = 21.142 eV
# Running simulation for omega = 21.143 eV
# Completed simulation for omega = 21.143 eV
# Running simulation for omega = 21.144 eV
# Completed simulation for omega = 21.144 eV
# Running simulation for omega = 21.145 eV
# Completed simulation for omega = 21.145 eV
# Running simulation for omega = 21.146 eV
# Completed simulation for omega = 21.146 eV
# Running simulation for omega = 21.147 eV
# Completed simulation for omega = 21.147 eV
# Running simulation for omega = 21.148 eV
# Completed simulation for omega = 21.148 eV
# Running simulation for omega = 21.149 eV
# Completed simulation for omega = 21.149 eV
# Running simulation for omega = 21.15 eV
# Completed simulation for omega = 21.15 eV
# Running simulation for omega = 21.151 eV
# Completed simulation for omega = 21.151 eV
# Running simulation for omega = 21.152 eV
# Completed simulation for omega = 21.152 eV
# Running simulation for omega = 21.153 eV
# Completed simulation for omega = 21.153 eV
# Running simulation for omega = 21.154 eV
# Completed simulation for omega = 21.154 eV
# Running simulation for omega = 21.155 eV
# Completed simulation for omega = 21.155 eV
# Running simulation for omega = 21.156 eV
# Completed simulation for omega = 21.156 eV
# Running simulation for omega = 21.157 eV
# Completed simulation for omega = 21.157 eV
# Running simulation for omega = 21.158 eV
# Completed simulation for omega = 21.158 eV
# Running simulation for omega = 21.159 eV
# Completed simulation for omega = 21.159 eV
# Running simulation for omega = 21.16 eV
# Completed simulation for omega = 21.16 eV
# Running simulation for omega = 21.161 eV
# Completed simulation for omega = 21.161 eV
# Running simulation for omega = 21.162 eV
# Completed simulation for omega = 21.162 eV
# Running simulation for omega = 21.163 eV
# Completed simulation for omega = 21.163 eV
# Running simulation for omega = 21.164 eV
# Completed simulation for omega = 21.164 eV
# Running simulation for omega = 21.165 eV
# Completed simulation for omega = 21.165 eV
# Running simulation for omega = 21.166 eV
# Completed simulation for omega = 21.166 eV
# Running simulation for omega = 21.167 eV
# Completed simulation for omega = 21.167 eV
# Running simulation for omega = 21.168 eV
# Completed simulation for omega = 21.168 eV
# Running simulation for omega = 21.169 eV
# Completed simulation for omega = 21.169 eV
# Running simulation for omega = 21.17 eV
# Completed simulation for omega = 21.17 eV
# Running simulation for omega = 21.171 eV
# Completed simulation for omega = 21.171 eV
# Running simulation for omega = 21.172 eV
# Completed simulation for omega = 21.172 eV
# Running simulation for omega = 21.173 eV
# Completed simulation for omega = 21.173 eV
# Running simulation for omega = 21.174 eV
# Completed simulation for omega = 21.174 eV
# Running simulation for omega = 21.175 eV
# Completed simulation for omega = 21.175 eV
# Running simulation for omega = 21.176 eV
# Completed simulation for omega = 21.176 eV
# Running simulation for omega = 21.177 eV
# Completed simulation for omega = 21.177 eV
# Running simulation for omega = 21.178 eV
# Completed simulation for omega = 21.178 eV
# Running simulation for omega = 21.179 eV
# Completed simulation for omega = 21.179 eV
# Running simulation for omega = 21.18 eV
# Completed simulation for omega = 21.18 eV
# Running simulation for omega = 21.181 eV
# Completed simulation for omega = 21.181 eV
# Running simulation for omega = 21.182 eV
# Completed simulation for omega = 21.182 eV
# Running simulation for omega = 21.183 eV
# Completed simulation for omega = 21.183 eV
# Running simulation for omega = 21.184 eV
# Completed simulation for omega = 21.184 eV
# Running simulation for omega = 21.185 eV
# Completed simulation for omega = 21.185 eV
# Running simulation for omega = 21.186 eV
# Completed simulation for omega = 21.186 eV
# Running simulation for omega = 21.187 eV
# Completed simulation for omega = 21.187 eV
# Running simulation for omega = 21.188 eV
# Completed simulation for omega = 21.188 eV
# Running simulation for omega = 21.189 eV
# Completed simulation for omega = 21.189 eV
# Running simulation for omega = 21.19 eV
# Completed simulation for omega = 21.19 eV
# Running simulation for omega = 21.191 eV
# Completed simulation for omega = 21.191 eV
# Running simulation for omega = 21.192 eV
# Completed simulation for omega = 21.192 eV
# Running simulation for omega = 21.193 eV
# Completed simulation for omega = 21.193 eV
# Running simulation for omega = 21.194 eV
# Completed simulation for omega = 21.194 eV
# Running simulation for omega = 21.195 eV
# Completed simulation for omega = 21.195 eV
# Running simulation for omega = 21.196 eV
# Completed simulation for omega = 21.196 eV
# Running simulation for omega = 21.197 eV
# Completed simulation for omega = 21.197 eV
# Running simulation for omega = 21.198 eV
# Completed simulation for omega = 21.198 eV
# Running simulation for omega = 21.199 eV
# Completed simulation for omega = 21.199 eV
# Running simulation for omega = 21.2 eV
# Completed simulation for omega = 21.2 eV
# Running simulation for omega = 21.201 eV
# Completed simulation for omega = 21.201 eV
# Running simulation for omega = 21.202 eV
# Completed simulation for omega = 21.202 eV
# Running simulation for omega = 21.203 eV
# Completed simulation for omega = 21.203 eV
# Running simulation for omega = 21.204 eV
# Completed simulation for omega = 21.204 eV
# Running simulation for omega = 21.205 eV
# Completed simulation for omega = 21.205 eV
# Running simulation for omega = 21.206 eV
# Completed simulation for omega = 21.206 eV
# Running simulation for omega = 21.207 eV
# Completed simulation for omega = 21.207 eV
# Running simulation for omega = 21.208 eV
# Completed simulation for omega = 21.208 eV
# Running simulation for omega = 21.209 eV
# Completed simulation for omega = 21.209 eV
# Running simulation for omega = 21.21 eV
# Completed simulation for omega = 21.21 eV
# Running simulation for omega = 21.211 eV
# Completed simulation for omega = 21.211 eV
# Running simulation for omega = 21.212 eV
# Completed simulation for omega = 21.212 eV
# Running simulation for omega = 21.213 eV
# Completed simulation for omega = 21.213 eV
# Running simulation for omega = 21.214 eV
# Completed simulation for omega = 21.214 eV
# Running simulation for omega = 21.215 eV
# Completed simulation for omega = 21.215 eV
# Running simulation for omega = 21.216 eV
# Completed simulation for omega = 21.216 eV
# Running simulation for omega = 21.217 eV
# Completed simulation for omega = 21.217 eV
# Running simulation for omega = 21.218 eV
# Completed simulation for omega = 21.218 eV
# Running simulation for omega = 21.219 eV
# Completed simulation for omega = 21.219 eV
# Running simulation for omega = 21.22 eV
# Completed simulation for omega = 21.22 eV
# Running simulation for omega = 21.221 eV
# Completed simulation for omega = 21.221 eV
# Running simulation for omega = 21.222 eV
# Completed simulation for omega = 21.222 eV
# Running simulation for omega = 21.223 eV
# Completed simulation for omega = 21.223 eV
# Running simulation for omega = 21.224 eV
# Completed simulation for omega = 21.224 eV
# Running simulation for omega = 21.225 eV
# Completed simulation for omega = 21.225 eV
# Running simulation for omega = 21.226 eV
# Completed simulation for omega = 21.226 eV
# Running simulation for omega = 21.227 eV
# Completed simulation for omega = 21.227 eV
# Running simulation for omega = 21.228 eV
# Completed simulation for omega = 21.228 eV
# Running simulation for omega = 21.229 eV
# Completed simulation for omega = 21.229 eV
# Running simulation for omega = 21.23 eV
# Completed simulation for omega = 21.23 eV
# Running simulation for omega = 21.231 eV
# Completed simulation for omega = 21.231 eV
# Running simulation for omega = 21.232 eV
# Completed simulation for omega = 21.232 eV
# Running simulation for omega = 21.233 eV
# Completed simulation for omega = 21.233 eV
# Running simulation for omega = 21.234 eV
# Completed simulation for omega = 21.234 eV
# Running simulation for omega = 21.235 eV
# Completed simulation for omega = 21.235 eV
# Running simulation for omega = 21.236 eV
# Completed simulation for omega = 21.236 eV
# Running simulation for omega = 21.237 eV
# Completed simulation for omega = 21.237 eV
# Running simulation for omega = 21.238 eV
# Completed simulation for omega = 21.238 eV
# Running simulation for omega = 21.239 eV
# Completed simulation for omega = 21.239 eV
# Running simulation for omega = 21.24 eV
# Completed simulation for omega = 21.24 eV
# Running simulation for omega = 21.241 eV
# Completed simulation for omega = 21.241 eV
# Running simulation for omega = 21.242 eV
# Completed simulation for omega = 21.242 eV
# Running simulation for omega = 21.243 eV
# Completed simulation for omega = 21.243 eV
# Running simulation for omega = 21.244 eV
# Completed simulation for omega = 21.244 eV
# Running simulation for omega = 21.245 eV
# Completed simulation for omega = 21.245 eV
# Running simulation for omega = 21.246 eV
# Completed simulation for omega = 21.246 eV
# Running simulation for omega = 21.247 eV
# Completed simulation for omega = 21.247 eV
# Running simulation for omega = 21.248 eV
# Completed simulation for omega = 21.248 eV
# Running simulation for omega = 21.249 eV
# Completed simulation for omega = 21.249 eV
# Running simulation for omega = 21.25 eV
# Completed simulation for omega = 21.25 eV
# Running simulation for omega = 21.251 eV
# Completed simulation for omega = 21.251 eV
# Running simulation for omega = 21.252 eV
# Completed simulation for omega = 21.252 eV
# Running simulation for omega = 21.253 eV
# Completed simulation for omega = 21.253 eV
# Running simulation for omega = 21.254 eV
# Completed simulation for omega = 21.254 eV
# Running simulation for omega = 21.255 eV
# Completed simulation for omega = 21.255 eV
# Running simulation for omega = 21.256 eV
# Completed simulation for omega = 21.256 eV
# Running simulation for omega = 21.257 eV
# Completed simulation for omega = 21.257 eV
# Running simulation for omega = 21.258 eV
# Completed simulation for omega = 21.258 eV
# Running simulation for omega = 21.259 eV
# Completed simulation for omega = 21.259 eV
# Running simulation for omega = 21.26 eV
# Completed simulation for omega = 21.26 eV
# Running simulation for omega = 21.261 eV
# Completed simulation for omega = 21.261 eV
# Running simulation for omega = 21.262 eV
# Completed simulation for omega = 21.262 eV
# Running simulation for omega = 21.263 eV
# Completed simulation for omega = 21.263 eV
# Running simulation for omega = 21.264 eV
# Completed simulation for omega = 21.264 eV
# Running simulation for omega = 21.265 eV
# Completed simulation for omega = 21.265 eV
# Running simulation for omega = 21.266 eV
# Completed simulation for omega = 21.266 eV
# Running simulation for omega = 21.267 eV
# Completed simulation for omega = 21.267 eV
# Running simulation for omega = 21.268 eV
# Completed simulation for omega = 21.268 eV
# Running simulation for omega = 21.269 eV
# Completed simulation for omega = 21.269 eV
# Running simulation for omega = 21.27 eV
# Completed simulation for omega = 21.27 eV
# Running simulation for omega = 21.271 eV
# Completed simulation for omega = 21.271 eV
# Running simulation for omega = 21.272 eV
# Completed simulation for omega = 21.272 eV
# Running simulation for omega = 21.273 eV
# Completed simulation for omega = 21.273 eV
# Running simulation for omega = 21.274 eV
# Completed simulation for omega = 21.274 eV
# Running simulation for omega = 21.275 eV
# Completed simulation for omega = 21.275 eV
# Running simulation for omega = 21.276 eV
# Completed simulation for omega = 21.276 eV
# Running simulation for omega = 21.277 eV
# Completed simulation for omega = 21.277 eV
# Running simulation for omega = 21.278 eV
# Completed simulation for omega = 21.278 eV
# Running simulation for omega = 21.279 eV
# Completed simulation for omega = 21.279 eV
# Running simulation for omega = 21.28 eV
# Completed simulation for omega = 21.28 eV
# Running simulation for omega = 21.281 eV
# Completed simulation for omega = 21.281 eV
# Running simulation for omega = 21.282 eV
# Completed simulation for omega = 21.282 eV
# Running simulation for omega = 21.283 eV
# Completed simulation for omega = 21.283 eV
# Running simulation for omega = 21.284 eV
# Completed simulation for omega = 21.284 eV
# Running simulation for omega = 21.285 eV
# Completed simulation for omega = 21.285 eV
# Running simulation for omega = 21.286 eV
# Completed simulation for omega = 21.286 eV
# Running simulation for omega = 21.287 eV
# Completed simulation for omega = 21.287 eV
# Running simulation for omega = 21.288 eV
# Completed simulation for omega = 21.288 eV
# Running simulation for omega = 21.289 eV
# Completed simulation for omega = 21.289 eV
# Running simulation for omega = 21.29 eV
# Completed simulation for omega = 21.29 eV
# Running simulation for omega = 21.291 eV
# Completed simulation for omega = 21.291 eV
# Running simulation for omega = 21.292 eV
# Completed simulation for omega = 21.292 eV
# Running simulation for omega = 21.293 eV
# Completed simulation for omega = 21.293 eV
# Running simulation for omega = 21.294 eV
# Completed simulation for omega = 21.294 eV
# Running simulation for omega = 21.295 eV
# Completed simulation for omega = 21.295 eV
# Running simulation for omega = 21.296 eV
# Completed simulation for omega = 21.296 eV
# Running simulation for omega = 21.297 eV
# Completed simulation for omega = 21.297 eV
# Running simulation for omega = 21.298 eV
# Completed simulation for omega = 21.298 eV
# Running simulation for omega = 21.299 eV
# Completed simulation for omega = 21.299 eV
# All simulations completed and results saved to simulation_results_optimisized_50fs_V3.3

# %%
populations = []
populationp = []
populationes = []
populationep = []
populationed = []
iloc_val = indices[- 1]
for omega_ev in omega_values:
    #print(omega_ev)
    df = results_dfp[f'df_pop_{omega_ev}']
    populations.append(df['s'].iloc[iloc_val])
    populationp.append(df['p'].iloc[iloc_val])
    populationes.append(df['es'].iloc[iloc_val])
    populationep.append(df['ep'].iloc[iloc_val])
    populationed.append(df['ed'].iloc[iloc_val])

# %%
#populations = np.array(populations).astype(int)
plt.figure()
plt.scatter(omega_values, populations, marker='x', label='s' , color='red')
plt.scatter(omega_values, populationp, marker='.', label='p', color='blue')
plt.scatter(omega_values, populationes, marker='x', label='es', color='green')
plt.scatter(omega_values, populationep, marker='.', label='ep', color='orange')
plt.plot(omega_values, populationed, label='ed', marker='o', color='purple')
plt.title('Population of states')
plt.xlabel('Omega (eV)')
plt.ylabel('Population')
#plt.legend(['s', 'p', 'es', 'pes', 'ed'])
#plt.legend(['es', 'ep', 'ed'])
plt.legend()
#plt.xlim(21.09, 21.2)
#plt.ylim(0, 3e-17)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
#populations = np.array(populations).astype(int)
plt.figure()
#plt.scatter(omega_values, populations, marker='x', label='s' , color='red')
#plt.scatter(omega_values, populationp, marker='.', label='p', color='blue')
plt.plot(omega_values, populationes, marker='x', label='es', color='green')
#plt.plot(omega_values, populationep, marker='.', label='ep', color='orange')
plt.plot(omega_values, populationed, label='ed', marker='o', color='purple')
#plt.axvline(x=Ecooper, color='brown', linestyle='--', label='Cooper Minimum')
#plt.axvline(x=Eres, color='black', linestyle='--', label='Resonance')
plt.title('Population of states')
plt.xlabel('Omega (eV)')
plt.ylabel('Population')
plt.legend()
#plt.xlim(21.09, 21.35)
#plt.ylim(0, 3e-17)
plt.show()
#plt.close()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Compare with Chris Green values

# %%
data=np.loadtxt('c_phi_spd_40_45 (no phase jumps).dat',skiprows=1)
data[1294:2874,2]=-data[1294:2874,2]
data[1294:1564,6]=-data[1294:1564,6]

# %%
Ew= E0_au
E2w= E02_au

DeltaPhi=0

omega=data[:,1]/2
c0=data[:,2]*Ew**2
c1=data[:,4]*E2w
c2=data[:,6]*Ew**2
phi0=data[:,3]
phi1=data[:,5]
phi2=data[:,7]

Wtot=c0**2 + c1**2 + c2**2
beta1=(2*np.sqrt(3)*c0*c1*np.cos(DeltaPhi-(phi0-phi1))
      +(4/np.sqrt(3))*c1*c2*np.cos(DeltaPhi-(phi2-phi1)))/Wtot
beta2=(2*c1**2 + (10/7)*c2**2 + 2*np.sqrt(5)*c0*c2*np.cos(phi2-phi0))/Wtot
beta3=((6/np.sqrt(3))*c1*c2*np.cos(DeltaPhi-(phi2-phi1)))/Wtot
beta4=((18/7)*c2**2)/Wtot

Ecooper=(-c2[1563]/(c2[1564]-c2[1563]))*(omega[1564]-omega[1563])+omega[1563]
Eres=21.216174

# %%
# %matplotlib inline
plt.scatter(omega, c0, marker='x', label='es', color='green')
plt.scatter(omega, c1, marker='.', label='ep', color='orange')
plt.scatter(omega, c2, label='ed', marker='o', color='purple')
plt.title('Population of states at 1000 fs')
plt.xlabel('Omega (eV)')
plt.ylabel('Population')
#plt.legend(['s', 'p', 'es', 'pes', 'ed'])
#plt.legend(['es', 'ep', 'ed'])
plt.legend()
plt.xlim(21.175, 21.2)
plt.show()

# %%
# %matplotlib widget

# %%
fig,ax = plt.subplots()
ax.plot(omega,c0,'.',label='s wave',markersize=2)
ax.plot(omega,c1,'.',label='p wave',markersize=2)
ax.plot(omega,c2,'.',label='d wave',markersize=2)
ax.axvline(x=Ecooper,color='black')
ax.axvline(x=Eres,color='black',ls='dashdot')
ax.axhline(y=0,color='black',ls='--')
#plt.yscale('symlog')
ax.set_xlabel(r'$\omega$ Photon energy (eV)')
ax.set_ylabel('Amplitude (a.u.)')
#ax.set_xlim(21.2161,21.2162)
#ax.set_ylim(-0.02,0.02)
plt.legend()
ax2=ax.secondary_xaxis('top',functions=(lambda x:x*2, lambda x:x/2))
ax2.set_xlabel(r'2$\omega$ Photon energy (eV)')
plt.show()
#plt.close()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
