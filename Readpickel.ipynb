# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os 

#%matplotlib widget
os.chdir('/asap3/flash/gpfs/fl26/2023/data/11015602/shared/Harijyoti/simulation_results_optimisized_25fs_V3.1')
os.getcwd()
# Out:
# '/asap3/flash/gpfs/fl26/2023/data/11015602/shared/Harijyoti/simulation_results_optimisized_25fs_V3.1'

# %%
ls
# Out:
# pop_t_stepseV_0.001_21.101_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.102_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.103_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.104_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.105_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.106_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.107_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.108_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.109_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.111_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.112_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.113_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.114_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.115_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.116_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.117_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.118_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.119_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.11_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.121_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.122_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.123_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.124_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.125_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.126_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.127_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.128_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.129_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.12_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.131_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.132_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.133_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.134_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.135_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.136_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.137_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.138_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.139_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.13_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.141_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.142_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.143_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.144_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.145_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.146_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.147_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.148_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.149_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.14_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.151_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.152_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.153_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.154_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.155_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.156_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.157_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.158_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.159_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.15_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.161_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.162_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.163_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.164_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.165_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.166_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.167_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.168_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.169_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.16_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.171_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.172_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.173_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.174_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.175_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.176_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.177_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.178_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.179_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.17_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.181_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.182_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.183_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.184_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.185_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.186_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.187_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.188_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.189_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.18_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.191_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.192_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.193_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.194_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.195_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.196_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.197_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.198_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.199_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.19_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.1_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.1_d_sep_0.0002_d_pes0.001_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.201_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.202_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.203_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.204_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.205_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.206_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.207_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.208_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.209_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.211_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.212_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.213_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.214_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.215_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.216_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.217_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.218_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.219_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.21_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.221_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.222_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.223_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.224_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.225_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.226_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.227_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.228_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.229_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.22_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.231_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.232_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.233_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.234_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.235_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.236_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.237_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.238_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.239_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.23_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.241_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.242_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.243_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.244_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.245_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.246_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.247_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.248_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.249_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.24_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.251_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.252_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.253_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.254_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.255_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.256_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.257_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.258_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.259_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.25_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.261_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.262_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.263_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.264_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.265_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.266_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.267_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.268_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.269_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.26_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.271_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.272_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.273_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.274_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.275_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.276_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.277_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.278_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.279_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.27_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.281_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.282_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.283_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.284_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.285_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.286_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.287_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.288_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.289_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.28_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.291_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.292_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.293_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.294_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.295_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.296_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.297_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.298_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.299_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.29_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.001_21.2_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.01_21.11_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.01_21.12_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.01_21.13_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.01_21.14_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.01_21.15_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.01_21.16_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.01_21.17_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.01_21.18_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.01_21.19_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.01_21.1_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.01_21.21_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.01_21.22_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.01_21.23_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.01_21.24_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.01_21.25_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.01_21.26_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.01_21.27_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.01_21.28_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.01_21.29_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# pop_t_stepseV_0.01_21.2_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.101_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.102_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.103_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.104_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.105_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.106_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.107_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.108_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.109_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.111_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.112_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.113_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.114_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.115_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.116_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.117_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.118_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.119_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.11_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.121_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.122_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.123_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.124_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.125_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.126_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.127_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.128_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.129_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.12_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.131_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.132_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.133_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.134_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.135_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.136_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.137_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.138_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.139_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.13_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.141_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.142_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.143_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.144_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.145_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.146_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.147_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.148_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.149_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.14_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.151_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.152_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.153_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.154_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.155_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.156_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.157_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.158_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.159_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.15_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.161_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.162_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.163_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.164_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.165_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.166_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.167_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.168_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.169_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.16_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.171_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.172_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.173_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.174_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.175_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.176_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.177_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.178_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.179_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.17_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.181_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.182_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.183_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.184_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.185_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.186_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.187_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.188_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.189_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.18_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.191_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.192_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.193_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.194_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.195_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.196_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.197_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.198_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.199_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.19_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.1_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.1_d_sep_0.0002_d_pes0.001_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.201_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.202_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.203_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.204_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.205_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.206_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.207_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.208_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.209_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.211_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.212_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.213_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.214_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.215_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.216_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.217_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.218_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.219_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.21_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.221_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.222_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.223_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.224_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.225_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.226_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.227_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.228_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.229_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.22_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.231_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.232_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.233_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.234_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.235_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.236_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.237_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.238_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.239_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.23_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.241_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.242_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.243_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.244_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.245_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.246_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.247_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.248_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.249_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.24_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.251_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.252_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.253_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.254_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.255_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.256_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.257_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.258_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.259_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.25_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.261_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.262_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.263_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.264_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.265_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.266_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.267_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.268_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.269_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.26_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.271_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.272_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.273_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.274_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.275_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.276_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.277_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.278_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.279_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.27_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.281_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.282_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.283_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.284_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.285_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.286_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.287_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.288_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.289_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.28_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.291_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.292_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.293_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.294_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.295_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.296_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.297_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.298_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.299_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.29_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.001_21.2_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.01_21.11_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.01_21.12_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.01_21.13_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.01_21.14_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.01_21.15_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.01_21.16_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.01_21.17_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.01_21.18_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.01_21.19_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.01_21.1_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.01_21.21_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.01_21.22_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.01_21.23_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.01_21.24_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.01_21.25_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.01_21.26_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.01_21.27_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.01_21.28_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.01_21.29_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# psi_t_stepseV_0.01_21.2_d_sep_0.0002_d_pes0.0015_d_ped_0.001.csv
# results_dfp_stepseV_0.001_d_sep_0.0002_d_pes0.0015_d_ped_0.001.pkl
# results_dfp_stepseV_0.01_d_sep_0.0002_d_pes0.0015_d_ped_0.001.pkl
# results_dfs_stepseV_0.001_d_sep_0.0002_d_pes0.0015_d_ped_0.001.pkl
# results_dfs_stepseV_0.01_d_sep_0.0002_d_pes0.0015_d_ped_0.001.pkl

# %%
# Time array(in fs)
start_time = -200  # fs
stop_time = 200 # fs
steps = 100000  # steps

t_values_SI = np.linspace(start_time, stop_time, steps)  # Time array in femtoseconds
t_values = t_values_SI * 41  # Time array in atomic units

# Time step
dt = t_values[1] - t_values[0]
timestep = 25 #fs
index_25 = np.where(t_values_SI > -timestep)[0]
index_26 = np.where(t_values_SI < timestep)[0]
subarray = t_values_SI[index_25[0]:index_26[-1]]

# %%
np.where(t_values_SI[-1])[0]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 np.where(t_values_SI[-1])[0]
#
# ValueError: Calling nonzero on 0d arrays is not allowed. Use np.atleast_1d(scalar).nonzero() instead.

# %%
results_dfp = pd.read_pickle('results_dfp_stepseV_0.001_d_sep_0.0002_d_pes0.0015_d_ped_0.001.pkl')

# %%
populations = []
populationp = []
populationes = []
populationep = []
populationed = []
iloc_val = np.where(t_values_SI[-1])[0]
steps_eV = 0.001
omega_values = np.round(np.arange(21.1, 21.3, steps_eV), 3)
for omega_ev in omega_values:
    #print(omega_ev)
    df = results_dfp[f'df_pop_{omega_ev}']
    populations.append(df['s'].iloc[iloc_val])
    populationp.append(df['p'].iloc[iloc_val])
    populationes.append(df['es'].iloc[iloc_val])
    populationep.append(df['ep'].iloc[iloc_val])
    populationed.append(df['ed'].iloc[iloc_val])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[45], line 6
#       4 populationep = []
#       5 populationed = []
# ----> 6 iloc_val = np.where(t_values_SI[-1])[0]
#       7 steps_eV = 0.001
#       8 omega_values = np.round(np.arange(21.1, 21.3, steps_eV), 3)
#
# ValueError: Calling nonzero on 0d arrays is not allowed. Use np.atleast_1d(scalar).nonzero() instead.

# %%
#populations = np.array(populations).astype(int)
# %matplotlib inline
plt.figure()
plt.scatter(omega_values, populations, marker='x', label='s' , color='red')
plt.plot(omega_values, populationp, marker='.', label='p', color='blue')
plt.scatter(omega_values, populationes, marker='x', label='es', color='green')
#plt.scatter(omega_values, populationep, marker='.', label='ep', color='orange')
plt.plot(omega_values, populationed, label='ed', marker='o', color='purple')
plt.title('Population of states')
plt.xlabel('Omega (eV)')
plt.ylabel('Population')
#plt.legend(['s', 'p', 'es', 'pes', 'ed'])
#plt.legend(['es', 'ep', 'ed'])
plt.legend()
#plt.xlim(21.09, 21.2)
#plt.ylim(0, 3e-17)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[25], line 4
#       2 get_ipython().run_line_magic('matplotlib', 'inline')
#       3 plt.figure()
# ----> 4 plt.scatter(omega_values, populations, marker='x', label='s' , color='red')
#       5 plt.plot(omega_values, populationp, marker='.', label='p', color='blue')
#       6 plt.scatter(omega_values, populationes, marker='x', label='es', color='green')
#
# File /asap3/flash/gpfs/fl26/2023/data/11015602/processed/flashremi_pipeline/.env/flashremi/lib/python3.12/site-packages/matplotlib/pyplot.py:3903, in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, data, **kwargs)
#    3884 @_copy_docstring_and_deprecators(Axes.scatter)
#    3885 def scatter(
#    3886     x: float | ArrayLike,
#    (...)
#    3901     **kwargs,
#    3902 ) -> PathCollection:
# -> 3903     __ret = gca().scatter(
#    3904         x,
#    3905         y,
#    3906         s=s,
#    3907         c=c,
#    3908         marker=marker,
#    3909         cmap=cmap,
#    3910         norm=norm,
#    3911         vmin=vmin,
#    3912         vmax=vmax,
#    3913         alpha=alpha,
#    3914         linewidths=linewidths,
#    3915         edgecolors=edgecolors,
#    3916         plotnonfinite=plotnonfinite,
#    3917         **({"data": data} if data is not None else {}),
#    3918         **kwargs,
#    3919     )
#    3920     sci(__ret)
#    3921     return __ret
#
# File /asap3/flash/gpfs/fl26/2023/data/11015602/processed/flashremi_pipeline/.env/flashremi/lib/python3.12/site-packages/matplotlib/__init__.py:1473, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1470 @functools.wraps(func)
#    1471 def inner(ax, *args, data=None, **kwargs):
#    1472     if data is None:
# -> 1473         return func(
#    1474             ax,
#    1475             *map(sanitize_sequence, args),
#    1476             **{k: sanitize_sequence(v) for k, v in kwargs.items()})
#    1478     bound = new_sig.bind(ax, *args, **kwargs)
#    1479     auto_label = (bound.arguments.get(label_namer)
#    1480                   or bound.kwargs.get(label_namer))
#
# File /asap3/flash/gpfs/fl26/2023/data/11015602/processed/flashremi_pipeline/.env/flashremi/lib/python3.12/site-packages/matplotlib/axes/_axes.py:4787, in Axes.scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, **kwargs)
#    4785 y = np.ma.ravel(y)
#    4786 if x.size != y.size:
# -> 4787     raise ValueError("x and y must be the same size")
#    4789 if s is None:
#    4790     s = (20 if mpl.rcParams['_internal.classic_mode'] else
#    4791          mpl.rcParams['lines.markersize'] ** 2.0)
#
# ValueError: x and y must be the same size

# %%
#populations = np.array(populations).astype(int)
plt.figure()
#plt.scatter(omega_values, populations, marker='x', label='s' , color='red')
#plt.scatter(omega_values, populationp, marker='.', label='p', color='blue')
plt.plot(omega_values, populationes, marker='x', label='es', color='green')
#plt.plot(omega_values, populationep, marker='.', label='ep', color='orange')
plt.plot(omega_values, populationed, label='ed', marker='o', color='purple')
#plt.axvline(x=Ecooper, color='brown', linestyle='--', label='Cooper Minimum')
#plt.axvline(x=Eres, color='black', linestyle='--', label='Resonance')
plt.title('Population of states')
plt.xlabel('Omega (eV)')
plt.ylabel('Population')
plt.legend()
#plt.xlim(21.09, 21.35)
#plt.ylim(0, 3e-17)
plt.show()
#plt.close()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 16
#      13 plt.legend()
#      14 #plt.xlim(21.09, 21.35)
#      15 #plt.ylim(0, 3e-17)
# ---> 16 plt.show()
#      17 #plt.close()
#
# File /asap3/flash/gpfs/fl26/2023/data/11015602/processed/flashremi_pipeline/.env/flashremi/lib/python3.12/site-packages/matplotlib/pyplot.py:612, in show(*args, **kwargs)
#     568 """
#     569 Display all open figures.
#     570
#    (...)
#     609 explicitly there.
#     610 """
#     611 _warn_if_gui_out_of_main_thread()
# --> 612 return _get_backend_mod().show(*args, **kwargs)
#
# File /asap3/flash/gpfs/fl26/2023/data/11015602/processed/flashremi_pipeline/.env/flashremi/lib/python3.12/site-packages/matplotlib_inline/backend_inline.py:90, in show(close, block)
#      88 try:
#      89     for figure_manager in Gcf.get_all_fig_managers():
# ---> 90         display(
#      91             figure_manager.canvas.figure,
#      92             metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      93         )
#      94 finally:
#      95     show._to_draw = []
#
# File /asap3/flash/gpfs/fl26/2023/data/11015602/processed/flashremi_pipeline/.env/flashremi/lib/python3.12/site-packages/IPython/core/display_functions.py:298, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     296     publish_display_data(data=obj, metadata=metadata, **kwargs)
#     297 else:
# --> 298     format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     299     if not format_dict:
#     300         # nothing to display (e.g. _ipython_display_ took over)
#     301         continue
#
# File /asap3/flash/gpfs/fl26/2023/data/11015602/processed/flashremi_pipeline/.env/flashremi/lib/python3.12/site-packages/IPython/core/formatters.py:182, in DisplayFormatter.format(self, obj, include, exclude)
#     180 md = None
#     181 try:
# --> 182     data = formatter(obj)
#     183 except:
#     184     # FIXME: log the exception
#     185     raise
#
# File /asap3/flash/gpfs/fl26/2023/data/11015602/processed/flashremi_pipeline/.env/flashremi/lib/python3.12/site-packages/decorator.py:232, in decorate.<locals>.fun(*args, **kw)
#     230 if not kwsyntax:
#     231     args, kw = fix(args, kw, sig)
# --> 232 return caller(func, *(extras + args), **kw)
#
# File /asap3/flash/gpfs/fl26/2023/data/11015602/processed/flashremi_pipeline/.env/flashremi/lib/python3.12/site-packages/IPython/core/formatters.py:226, in catch_format_error(method, self, *args, **kwargs)
#     224 """show traceback on failed format call"""
#     225 try:
# --> 226     r = method(self, *args, **kwargs)
#     227 except NotImplementedError:
#     228     # don't warn on NotImplementedErrors
#     229     return self._check_return(None, args[0])
#
# File /asap3/flash/gpfs/fl26/2023/data/11015602/processed/flashremi_pipeline/.env/flashremi/lib/python3.12/site-packages/IPython/core/formatters.py:343, in BaseFormatter.__call__(self, obj)
#     341     pass
#     342 else:
# --> 343     return printer(obj)
#     344 # Finally look for special method names
#     345 method = get_real_method(obj, self.print_method)
#
# File /asap3/flash/gpfs/fl26/2023/data/11015602/processed/flashremi_pipeline/.env/flashremi/lib/python3.12/site-packages/IPython/core/pylabtools.py:170, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     167     from matplotlib.backend_bases import FigureCanvasBase
#     168     FigureCanvasBase(fig)
# --> 170 fig.canvas.print_figure(bytes_io, **kw)
#     171 data = bytes_io.getvalue()
#     172 if fmt == 'svg':
#
# File /asap3/flash/gpfs/fl26/2023/data/11015602/processed/flashremi_pipeline/.env/flashremi/lib/python3.12/site-packages/matplotlib/backend_bases.py:2175, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2172     # we do this instead of `self.figure.draw_without_rendering`
#    2173     # so that we can inject the orientation
#    2174     with getattr(renderer, "_draw_disabled", nullcontext)():
# -> 2175         self.figure.draw(renderer)
#    2176 if bbox_inches:
#    2177     if bbox_inches == "tight":
#
# File /asap3/flash/gpfs/fl26/2023/data/11015602/processed/flashremi_pipeline/.env/flashremi/lib/python3.12/site-packages/matplotlib/artist.py:95, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      93 @wraps(draw)
#      94 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 95     result = draw(artist, renderer, *args, **kwargs)
#      96     if renderer._rasterizing:
#      97         renderer.stop_rasterizing()
#
# File /asap3/flash/gpfs/fl26/2023/data/11015602/processed/flashremi_pipeline/.env/flashremi/lib/python3.12/site-packages/matplotlib/artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File /asap3/flash/gpfs/fl26/2023/data/11015602/processed/flashremi_pipeline/.env/flashremi/lib/python3.12/site-packages/matplotlib/figure.py:3162, in Figure.draw(self, renderer)
#    3159             # ValueError can occur when resizing a window.
#    3161     self.patch.draw(renderer)
# -> 3162     mimage._draw_list_compositing_images(
#    3163         renderer, self, artists, self.suppressComposite)
#    3165     renderer.close_group('figure')
#    3166 finally:
#
# File /asap3/flash/gpfs/fl26/2023/data/11015602/processed/flashremi_pipeline/.env/flashremi/lib/python3.12/site-packages/matplotlib/image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File /asap3/flash/gpfs/fl26/2023/data/11015602/processed/flashremi_pipeline/.env/flashremi/lib/python3.12/site-packages/matplotlib/artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File /asap3/flash/gpfs/fl26/2023/data/11015602/processed/flashremi_pipeline/.env/flashremi/lib/python3.12/site-packages/matplotlib/axes/_base.py:3137, in _AxesBase.draw(self, renderer)
#    3134 if artists_rasterized:
#    3135     _draw_rasterized(self.figure, artists_rasterized, renderer)
# -> 3137 mimage._draw_list_compositing_images(
#    3138     renderer, self, artists, self.figure.suppressComposite)
#    3140 renderer.close_group('axes')
#    3141 self.stale = False
#
# File /asap3/flash/gpfs/fl26/2023/data/11015602/processed/flashremi_pipeline/.env/flashremi/lib/python3.12/site-packages/matplotlib/image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File /asap3/flash/gpfs/fl26/2023/data/11015602/processed/flashremi_pipeline/.env/flashremi/lib/python3.12/site-packages/matplotlib/artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File /asap3/flash/gpfs/fl26/2023/data/11015602/processed/flashremi_pipeline/.env/flashremi/lib/python3.12/site-packages/matplotlib/legend.py:766, in Legend.draw(self, renderer)
#     762     self._legend_box.set_width(self.get_bbox_to_anchor().width - pad)
#     764 # update the location and size of the legend. This needs to
#     765 # be done in any case to clip the figure right.
# --> 766 bbox = self._legend_box.get_window_extent(renderer)
#     767 self.legendPatch.set_bounds(bbox.bounds)
#     768 self.legendPatch.set_mutation_scale(fontsize)
#
# File /asap3/flash/gpfs/fl26/2023/data/11015602/processed/flashremi_pipeline/.env/flashremi/lib/python3.12/site-packages/matplotlib/offsetbox.py:367, in OffsetBox.get_window_extent(self, renderer)
#     365 if renderer is None:
#     366     renderer = self.figure._get_renderer()
# --> 367 bbox = self.get_bbox(renderer)
#     368 try:  # Some subclasses redefine get_offset to take no args.
#     369     px, py = self.get_offset(bbox, renderer)
#
# File /asap3/flash/gpfs/fl26/2023/data/11015602/processed/flashremi_pipeline/.env/flashremi/lib/python3.12/site-packages/matplotlib/offsetbox.py:360, in OffsetBox.get_bbox(self, renderer)
#     358 def get_bbox(self, renderer):
#     359     """Return the bbox of the offsetbox, ignoring parent offsets."""
# --> 360     bbox, offsets = self._get_bbox_and_child_offsets(renderer)
#     361     return bbox
#
# File /asap3/flash/gpfs/fl26/2023/data/11015602/processed/flashremi_pipeline/.env/flashremi/lib/python3.12/site-packages/matplotlib/offsetbox.py:452, in VPacker._get_bbox_and_child_offsets(self, renderer)
#     449         if isinstance(c, PackerBase) and c.mode == "expand":
#     450             c.set_width(self.width)
# --> 452 bboxes = [c.get_bbox(renderer) for c in self.get_visible_children()]
#     453 (x0, x1), xoffsets = _get_aligned_offsets(
#     454     [bbox.intervalx for bbox in bboxes], self.width, self.align)
#     455 height, yoffsets = _get_packed_offsets(
#     456     [bbox.height for bbox in bboxes], self.height, sep, self.mode)
#
# File /asap3/flash/gpfs/fl26/2023/data/11015602/processed/flashremi_pipeline/.env/flashremi/lib/python3.12/site-packages/matplotlib/offsetbox.py:360, in OffsetBox.get_bbox(self, renderer)
#     358 def get_bbox(self, renderer):
#     359     """Return the bbox of the offsetbox, ignoring parent offsets."""
# --> 360     bbox, offsets = self._get_bbox_and_child_offsets(renderer)
#     361     return bbox
#
# File /asap3/flash/gpfs/fl26/2023/data/11015602/processed/flashremi_pipeline/.env/flashremi/lib/python3.12/site-packages/matplotlib/offsetbox.py:479, in HPacker._get_bbox_and_child_offsets(self, renderer)
#     476 pad = self.pad * dpicor
#     477 sep = self.sep * dpicor
# --> 479 bboxes = [c.get_bbox(renderer) for c in self.get_visible_children()]
#     480 if not bboxes:
#     481     return Bbox.from_bounds(0, 0, 0, 0).padded(pad), []
#
# File /asap3/flash/gpfs/fl26/2023/data/11015602/processed/flashremi_pipeline/.env/flashremi/lib/python3.12/site-packages/matplotlib/offsetbox.py:360, in OffsetBox.get_bbox(self, renderer)
#     358 def get_bbox(self, renderer):
#     359     """Return the bbox of the offsetbox, ignoring parent offsets."""
# --> 360     bbox, offsets = self._get_bbox_and_child_offsets(renderer)
#     361     return bbox
#
# File /asap3/flash/gpfs/fl26/2023/data/11015602/processed/flashremi_pipeline/.env/flashremi/lib/python3.12/site-packages/matplotlib/offsetbox.py:452, in VPacker._get_bbox_and_child_offsets(self, renderer)
#     449         if isinstance(c, PackerBase) and c.mode == "expand":
#     450             c.set_width(self.width)
# --> 452 bboxes = [c.get_bbox(renderer) for c in self.get_visible_children()]
#     453 (x0, x1), xoffsets = _get_aligned_offsets(
#     454     [bbox.intervalx for bbox in bboxes], self.width, self.align)
#     455 height, yoffsets = _get_packed_offsets(
#     456     [bbox.height for bbox in bboxes], self.height, sep, self.mode)
#
# File /asap3/flash/gpfs/fl26/2023/data/11015602/processed/flashremi_pipeline/.env/flashremi/lib/python3.12/site-packages/matplotlib/offsetbox.py:360, in OffsetBox.get_bbox(self, renderer)
#     358 def get_bbox(self, renderer):
#     359     """Return the bbox of the offsetbox, ignoring parent offsets."""
# --> 360     bbox, offsets = self._get_bbox_and_child_offsets(renderer)
#     361     return bbox
#
# File /asap3/flash/gpfs/fl26/2023/data/11015602/processed/flashremi_pipeline/.env/flashremi/lib/python3.12/site-packages/matplotlib/offsetbox.py:479, in HPacker._get_bbox_and_child_offsets(self, renderer)
#     476 pad = self.pad * dpicor
#     477 sep = self.sep * dpicor
# --> 479 bboxes = [c.get_bbox(renderer) for c in self.get_visible_children()]
#     480 if not bboxes:
#     481     return Bbox.from_bounds(0, 0, 0, 0).padded(pad), []
#
# File /asap3/flash/gpfs/fl26/2023/data/11015602/processed/flashremi_pipeline/.env/flashremi/lib/python3.12/site-packages/matplotlib/offsetbox.py:767, in TextArea.get_bbox(self, renderer)
#     762 def get_bbox(self, renderer):
#     763     _, h_, d_ = renderer.get_text_width_height_descent(
#     764         "lp", self._text._fontproperties,
#     765         ismath="TeX" if self._text.get_usetex() else False)
# --> 767     bbox, info, yd = self._text._get_layout(renderer)
#     768     w, h = bbox.size
#     770     self._baseline_transform.clear()
#
# File /asap3/flash/gpfs/fl26/2023/data/11015602/processed/flashremi_pipeline/.env/flashremi/lib/python3.12/site-packages/matplotlib/text.py:445, in Text._get_layout(self, renderer)
#     443 xmax = corners_rotated[:, 0].max()
#     444 ymin = corners_rotated[:, 1].min()
# --> 445 ymax = corners_rotated[:, 1].max()
#     446 width = xmax - xmin
#     447 height = ymax - ymin
#
# File /asap3/flash/gpfs/fl26/2023/data/11015602/processed/flashremi_pipeline/.env/flashremi/lib/python3.12/site-packages/numpy/_core/_methods.py:45, in _amax(a, axis, out, keepdims, initial, where)
#      43 def _amax(a, axis=None, out=None, keepdims=False,
#      44           initial=_NoValue, where=True):
# ---> 45     return umr_maximum(a, axis, None, out, keepdims, initial, where)
#
# KeyboardInterrupt:

# %%
#populations = np.array(populations).astype(int)
plt.figure()
#plt.scatter(omega_values, populations, marker='x', label='s' , color='red')
#plt.scatter(omega_values, populationp, marker='.', label='p', color='blue')
#plt.plot(omega_values, populationes, marker='x', label='es', color='green')
plt.plot(omega_values, populationep, marker='.', label='ep', color='orange')
#plt.plot(omega_values, populationed, label='ed', marker='o', color='purple')
#plt.axvline(x=Ecooper, color='brown', linestyle='--', label='Cooper Minimum')
#plt.axvline(x=Eres, color='black', linestyle='--', label='Resonance')
plt.title('Population of states')
plt.xlabel('Omega (eV)')
plt.ylabel('Population')
plt.legend()
#plt.xlim(21.09, 21.35)
#plt.ylim(0, 3e-17)
plt.show()
#plt.close()

# %%
populations = []
populationp = []
populationes = []
populationep = []
populationed = []
iloc_val = 99998
steps_eV = 0.001
omega_values = np.round(np.arange(21.1, 21.3, steps_eV), 3)
for omega_ev in omega_values:
    #print(omega_ev)
    df = results_dfp[f'df_pop_{omega_ev}']
    populations.append(df['s'])
    populationp.append(df['p'])
    populationes.append(df['es'])
    populationep.append(df['ep'])
    populationed.append(df['ed'])

# %%
t_values_SI1 = t_values_SI[0:-1]

# %%
# %matplotlib ipympl
# Electric field functions
def E_omega(t, E0_au, omega_au, t0_au, tau_au, phi1):
    # Set the time limit to 3 standard deviations (tau_au)
    t_limit = 3 * tau_au
    time_abs = np.abs(t - t0_au)
    
    return np.where(time_abs < t_limit, 
                    E0_au * np.exp(-((t - t0_au) / tau_au) ** 2) * ((np.cos(omega_au * t + phi1))**2), 
                    0)

def E_2omega(t, E02_au, omega_au, t0_au, tau_au, phi2):
    t_limit = 3 * tau_au
    time_abs = np.abs(t - t0_au)
    return np.where(time_abs < t_limit, 
                    E02_au * np.exp(-((t - t0_au) / tau_au) ** 2) * ((np.cos(2*omega_au * t + phi2))**2),
                    0)

# Electric Field parameters
phi1 = 0.0
phi2 = 0.0
tau = 50  # fs
tau_au = tau * 41
t0 = 0 # fs  # setting t0 to a non-zero value to avoid zero limit issue
t0_au = t0 * 41
E0_au = 0.0005
E02_au = 0.00005
omega_au = 21.2
E_om = E_omega(t_values, E0_au, omega_au, t0_au, tau_au, phi1)
E_2om = E_2omega(t_values, E02_au, omega_au, t0_au, tau_au, phi2)
plt.figure()
plt.plot(t_values_SI, E_om)
plt.plot(t_values_SI, E_2om)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.figure()
#plt.plot(t_values_SI1, populationes[100] - populationes[0])
#plt.plot(t_values_SI1, populationes[0])
#plt.plot(t_values_SI1, populationep[0])
plt.plot(t_values_SI1, populationep[100] - populationep[0])
#plt.plot(t_values_SI1, populationep[0] - populationep[-1])
#plt.plot(t_values_SI, E_om)
#plt.plot(t_values_SI1, populationes[0] - populations[-1])
plt.show()

# %%
plt.figure()
#plt.plot(t_values_SI1, populations[100] - populations[0])
plt.plot(t_values_SI1, populations[0] - populations[-1])
plt.show()

# %%
plt.figure()
#plt.scatter(t_values_SI1, populationes[0], marker = '.')
plt.plot(t_values_SI1, populationes[100], marker = 'o')
#plt.scatter(t_values_SI1, populationes[-1], marker = 'x')
#plt.xlim(-50,50)
plt.show()

# %%
plt.figure()
plt.scatter(t_values_SI1, populations[0], marker = '.')
plt.scatter(t_values_SI1, populations[100], marker = 'o')
#plt.scatter(t_values_SI1, populations[-1], marker = 'x')
plt.xlim(-50,50)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
populations[1]
# Out:
# 0        1.000000
# 1        1.000000
# 2        1.000000
# 3        1.000000
# 4        1.000000
#            ...
# 99994    0.999962
# 99995    0.999962
# 99996    0.999962
# 99997    0.999962
# 99998    0.999962
# Name: s, Length: 99999, dtype: float64
